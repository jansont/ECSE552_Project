# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
training = pd.read_csv('/Users/alixdanglejan-chatillon/ECSE552_Project/Results/TrainingResults1.csv')
validation = pd.read_csv('/Users/alixdanglejan-chatillon/ECSE552_Project/Results/ValidationResults1.csv')

# %%
def running_mean(x, N):
    cumsum = np.cumsum(np.insert(x, 0, 0)) 
    return (cumsum[N:] - cumsum[:-N]) / float(N)

L = np.array(training['Error'])
L = L[L < 1000]

L = running_mean(L, 100)
L = L[:40]
plt.plot([i for i in range(len(L))], L, label = 'Training')
V = np.array(validation['Error'].iloc[:40])

plt.plot([i for i in range(len(V))], V, label = 'Validation')
plt.legend()
plt.ylabel('MSE Loss'), plt.xlabel('Epochs')
plt.xlabel('Epoch')

#GCN PLOT
# Out:
# Text(0.5, 0, 'Epoch')

# %%
def running_mean(x, N):
    cumsum = np.cumsum(np.insert(x, 0, 0)) 
    return (cumsum[N:] - cumsum[:-N]) / float(N)


L = running_mean(np.array(training['Loss']), 100)
L = L[:15]**0.5
plt.plot([i for i in range(len(L))], L, label = 'Training')
V = np.array(validation['Loss'].iloc[:15])**0.5

plt.plot([i for i in range(len(V))], V, label = 'Validation')
plt.legend()
plt.ylabel('MSE Loss'), plt.xlabel('Epochs')
plt.xlabel('Epoch')
# Out:
# Text(0.5, 0, 'Epoch')

# %%
def running_mean(x, N):
    cumsum = np.cumsum(np.insert(x, 0, 0)) 
    return (cumsum[N:] - cumsum[:-N]) / float(N)


L = running_mean(np.array(training['Loss']), 100)
L = L[:15]**0.5
plt.plot([i for i in range(len(L))], L, label = 'Training')
V = np.array(validation['Loss'].iloc[:15])**0.5

plt.plot([i for i in range(len(V))], V, label = 'Validation')
plt.legend()
plt.ylabel('MSE Loss'), plt.xlabel('Epochs')
plt.xlabel('Epoch')
# Out:
# Text(0.5, 0, 'Epoch')

# %%
def running_mean(x, N):
    cumsum = np.cumsum(np.insert(x, 0, 0)) 
    return (cumsum[N:] - cumsum[:-N]) / float(N)


L = running_mean(np.array(training['Loss']), 100)
L = L[:15]**0.5
plt.plot([i for i in range(len(L))], L, label = 'Training')
V = np.array(validation['Loss'].iloc[:15])**0.5

plt.plot([i for i in range(len(V))], V, label = 'Validation')
plt.legend()
plt.ylabel('MSE Loss'), plt.xlabel('Epochs')
plt.xlabel('Epoch')
connv
# Out:
# Text(0.5, 0, 'Epoch')

# %%
def running_mean(x, N):
    cumsum = np.cumsum(np.insert(x, 0, 0)) 
    return (cumsum[N:] - cumsum[:-N]) / float(N)


L = running_mean(np.array(training['Loss']), 100)
L = L[:30]**0.5
plt.plot([i for i in range(len(L))], L, label = 'Training')
V = np.array(validation['Loss'].iloc[:30])**0.5

plt.plot([i for i in range(len(V))], V, label = 'Validation')
plt.legend()
plt.ylabel('MSE Loss'), plt.xlabel('Epochs')
plt.xlabel('Epoch')

#GCN PLOT
# Out:
# Text(0.5, 0, 'Epoch')

# %%
def running_mean(x, N):
    cumsum = np.cumsum(np.insert(x, 0, 0)) 
    return (cumsum[N:] - cumsum[:-N]) / float(N)


L = running_mean(np.array(training['Loss']), 100)
L = L[:40]
plt.plot([i for i in range(len(L))], L, label = 'Training')
V = np.array(validation['Loss'].iloc[:40])

plt.plot([i for i in range(len(V))], V, label = 'Validation')
plt.legend()
plt.ylabel('MSE Loss'), plt.xlabel('Epochs')
plt.xlabel('Epoch')

#GNN PLOT
# Out:
# Text(0.5, 0, 'Epoch')

# %%
def running_mean(x, N):
    cumsum = np.cumsum(np.insert(x, 0, 0)) 
    return (cumsum[N:] - cumsum[:-N]) / float(N)


L = running_mean(np.array(training['Loss']), 100)
L = L[:40]
plt.plot([i for i in range(len(L))], L, label = 'Training')
V = np.array(validation['Loss'].iloc[:40])

plt.plot([i for i in range(len(V))], V, label = 'Validation')
plt.legend()
plt.ylabel('MSE Loss'), plt.xlabel('Epochs')
plt.xlabel('Epoch')

#GCN PLOT
# Out:
# Text(0.5, 0, 'Epoch')
